# %%
from IPython.display import Image,display

# %% [markdown]
# Plano TIM PRÉ-PAGO
#
# 1,5 GB de internet
# 400 minutos qquer operadora
# Whatsapp à vontade
# SMS p/ qquer operadora
#
#
# 1. Ligar para o *144
# 2. Teclar #
# 3. Digitar 0 21 98142-3565
# 4. Falar com a atendente
#
#
# No dia 09/08 o plano foi ativado por R$ 34,99 e cancelado nessa madrugada 12/08 às 02:12
#
# * A primeira atendente disse que foi um erro e que iria estornar o valor e reativar a promoção. Porém a ligação foi desligada e mesma não retornou.
#
# * A segunda disse que só o titular poderia .....

# %% [markdown]
# Chegaram as mensagens

# %%
display(Image(filename="/home/claudio/Área de Trabalho/anexos/wp_ss_20170812_0001.jpg"))
display(Image(filename="/home/claudio/Área de Trabalho/anexos/wp_ss_20170812_0002.jpg"))
display(Image(filename="/home/claudio/Área de Trabalho/anexos/wp_ss_20170812_0003.jpg"))
